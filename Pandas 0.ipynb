# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv("datasets/oec.csv")

# %%
# Доступ по признаку
dataset['PlanetIdentifier']

# Получить ключи датасета
dataset.keys()

# Вывод данных
plt.plot(dataset['Eccentricity'])
plt.show()
